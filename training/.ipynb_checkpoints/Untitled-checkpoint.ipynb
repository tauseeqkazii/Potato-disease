# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE=256
BATCH_SIZE=32

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(
    "data-set",
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size= BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
plt.figure(figsize=(10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
train_size=0.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
train_ds=dataset.take(54)
len(train_ds)
# Out:
# 54

# %%
test_ds=dataset.skip(54)
len(test_ds)
# Out:
# 14

# %%
val_ds=test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds=test_ds.skip(6)
len(test_ds)
# Out:
# 8

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle_size=10000, shuffle=True):
    # Ensure that splits add up to 1
#     assert train_split + val_split + test_split == 1, "Splits must add up to 1"

    # Get the size of the dataset
    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size + val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds,val_ds,test_ds=get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
len(val_ds)
# Out:
# 6

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE) 
val_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE) 
test_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE) 

# prefetch for taking another datase4t if gpu or cpu is busy training it will take next set of batch to improve performace  
# cache -once the image is read it will keep it in the memory(improving performance)
#  here the data set is optimized

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE,IMAGE_SIZE),
#     helps image resize whose res is not 256*256
    layers.Rescaling(1.0/255)
])
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
#     flips the image 
    layers.RandomRotation(0.2)
#     rotates the image 
])


# this part is for optimizing the dataset

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 train_ds = train_ds.map(
#       2     lambda x, y: (data_augmentation(x, training=True), y)
#       3 ).prefetch(buffer_size=tf.data.AUTOTUNE)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2299, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2295 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2296 # dataset_ops).
#    2297 # pylint: disable=g-import-not-at-top,protected-access
#    2298 from tensorflow.python.data.ops import map_op
# -> 2299 return map_op._map_v2(
#    2300     self,
#    2301     map_func,
#    2302     num_parallel_calls=num_parallel_calls,
#    2303     deterministic=deterministic,
#    2304     name=name)
#
# ...
